# %% [markdown]
# https://data.world/cityofchicago/gumc-mgzr

# %% [markdown]
# Original Title: Violence Reduction - Victims of Homicides and Non-Fatal Shootings
#
# This dataset contains individual-level homicide and non-fatal shooting victimizations from 2016 to the present. Each row represents a single victimization, i.e., a unique event when an individual became the victim of a violent index crime. Each row does not represent a unique victim—if someone is victimized multiple times there will be multiple rows for each of those distinct events. These classifications are slightly different from the Chicago Police Department’s (CPD) traditional Illinois Uniform Crime Reporting (IUCR) classifications of criminal incidents. "Fatal Shooting," "Non-Shooting Homicide," and "Non-Fatal Shooting" are not IUCR primary descriptions (IUCR primary descriptions do not specify type of injury). However, due to the severity of gun violence in Chicago, the City has chosen to depart slightly from IUCR primary descriptions used in this dataset to highlight injuries caused by guns. The dataset is refreshed daily, but excludes the most recent complete day to allow CPD time to gather the best available information. Each time the dataset is refreshed, records can change as CPD learns more about each victimization, especially those victimizations that are most recent. The data on the Mayor's Office Violence Reduction Dashboard is updated daily with an approximately 48-hour lag. As cases are passed from the initial reporting officer to the investigating detectives, some recorded data about incidents and victimizations may change once additional information arises. Regularly updated datasets on the City's public portal may change to reflect new or corrected information. A version of this dataset with additional crime types is available by request. To make a request, please email dataportal@cityofchicago.org with the subject line: Violence Reduction Victims Access Request. Access will require an account on this site, which you may create at https://data.cityofchicago.org/signup. Note: The definition of “homicide” (shooting or otherwise) does not include justifiable homicide or involuntary manslaughter. This dataset also excludes any cases that CPD considers to be “unfounded” or “noncriminal.” Officer-involved shootings are also excluded; when an officer discharges their weapon, a separate case report is generated using one of the following IUCR codes: 5060, 5103, 5104, 5140, 5141, 5142. Note: The initial reporting officer usually asks victims to report demographic data. If victims are unable to recall, the reporting officer will use their best judgment. “Unknown” can be reported if it is truly unknown.
#
# Source: https://data.cityofchicago.org/d/gumc-mgzr
# Last updated at https://data.cityofchicago.org/ : 2021-05-29

# %% [markdown]
# ### Перевод:

# %% [markdown]
# Оригинальное название: Violence Reduction — Жертвы убийств и стрельбы без смертельного исхода
#
# Этот набор данных содержит индивидуальные убийства и несмертельные случаи стрельбы с 2016 года по настоящее время. Каждая строка представляет одну виктимизацию, т. е. уникальное событие, когда человек стал жертвой индексного насильственного преступления. Каждая строка не представляет уникальную жертву — если кто-то становится жертвой несколько раз, для каждого из этих отдельных событий будет несколько строк. Эти классификации немного отличаются от традиционных классификаций уголовных происшествий Департамента полиции Чикаго (CPD) Иллинойса. «Стрельба со смертельным исходом», «Убийство без стрельбы» и «Стрельба без смертельного исхода» не являются основными описаниями IUCR (в основных описаниях IUCR не указывается тип травмы). Однако из-за серьезности насилия с применением огнестрельного оружия в Чикаго городские власти решили немного отойти от основных описаний IUCR, используемых в этом наборе данных, чтобы выделить травмы, нанесенные огнестрельным оружием. Набор данных обновляется ежедневно, но исключает самый последний полный день, чтобы дать CPD время для сбора наилучшей доступной информации. Каждый раз, когда набор данных обновляется, записи могут меняться, поскольку CPD узнает больше о каждой виктимизации, особенно о самых последних виктимизациях. Данные на информационной панели мэрии по снижению уровня насилия обновляются ежедневно с задержкой примерно в 48 часов. По мере того, как дела передаются от сотрудника, ответственного за первоначальное сообщение, следователям, некоторые зарегистрированные данные об инцидентах и ​​виктимизации могут измениться по мере поступления дополнительной информации. Регулярно обновляемые наборы данных на публичном портале города могут меняться, чтобы отражать новую или исправленную информацию. Версия этого набора данных с дополнительными типами преступлений доступна по запросу. Чтобы сделать запрос, отправьте электронное письмо по адресу dataportal@cityofchicago.org, указав в строке темы: Запрос на доступ к жертвам сокращения насилия. Для доступа потребуется учетная запись на этом сайте, которую вы можете создать по адресу https://data.cityofchicago.org/signup. Примечание. Определение «убийство» (стрельба или иное) не включает оправданное убийство или непредумышленное убийство. Этот набор данных также исключает любые случаи, которые CPD считает «необоснованными» или «неуголовными». Стрельба с участием офицеров также исключена; когда офицер разряжает свое оружие, создается отдельный отчет о случае с использованием одного из следующих кодов IUCR: 5060, 5103, 5104, 5140, 5141, 5142. Примечание: первоначально сообщающий офицер обычно просит жертв сообщить демографические данные. Если потерпевшие не могут вспомнить, офицер-докладчик примет надлежащее решение. «Неизвестно» можно сообщить, если оно действительно неизвестно.
#
# Источник: https://data.cityofchicago.org/d/gumc-mgzr.
# Последнее обновление на https://data.cityofchicago.org/: 29 мая 2021 г.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/roman/violence_reduction/violence-reduction-victims-of-homicides-and-non-fatal-shootings-1.csv')

# %%
df.head(3)
# Out:
#   CASE_NUMBER                    DATE                BLOCK    PRIMARY_TYPE  \
# 0    JE235091  05/19/2021 11:20:00 AM    7400  S DR MARTIN  FATAL SHOOTING
# 1    JE240540  05/24/2021 12:01:00 AM  2000  N LARAMIE AVE  FATAL SHOOTING
# 2    JE241639  05/24/2021 09:05:00 PM   500  S OAKLEY BLVD  FATAL SHOOTING
#
#         UNIQUE_ID  ZIP_CODE  WARD          COMMUNITY_AREA  \
# 0  HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1  HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2  HOM-JE241639-1     60612    28          NEAR WEST SIDE
#
#       STREET OUTREACH ORGANIZATION  AREA  ...  FBI_CD  \
# 0  Acclivus Greater Grand Crossing     1  ...     01A
# 1              ALSO Belmont Cragin     3  ...     04B
# 2                             None     3  ...     01A
#
#                               FBI_DESCR IUCR_CD        IUCR_SECONDARY MONTH  \
# 0  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110   FIRST DEGREE MURDER     5
# 1            AGGRAVATED BATTERY (INDEX)    041A  AGGRAVATED - HANDGUN     5
# 2  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110   FIRST DEGREE MURDER     5
#
#   DAY_OF_WEEK HOUR   LATITUDE  LONGITUDE  \
# 0           4   11  41.759333 -87.615011
# 1           2    0  41.919410 -87.755999
# 2           2   21  41.875343 -87.684209
#
#                                    LOCATION
# 0  POINT (-87.615010941301 41.759333095858)
# 1  POINT (-87.755998547471 41.919409668947)
# 2  POINT (-87.684209058699 41.875343095858)
#
# [3 rows x 25 columns]

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head(3)
# Out:
#   case_number                    date                block    primary_type  \
# 0    JE235091  05/19/2021 11:20:00 AM    7400  S DR MARTIN  FATAL SHOOTING
# 1    JE240540  05/24/2021 12:01:00 AM  2000  N LARAMIE AVE  FATAL SHOOTING
# 2    JE241639  05/24/2021 09:05:00 PM   500  S OAKLEY BLVD  FATAL SHOOTING
#
#         unique_id  zip_code  ward          community_area  \
# 0  HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1  HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2  HOM-JE241639-1     60612    28          NEAR WEST SIDE
#
#       street_outreach_organization  area  ...  fbi_cd  \
# 0  Acclivus Greater Grand Crossing     1  ...     01A
# 1              ALSO Belmont Cragin     3  ...     04B
# 2                             None     3  ...     01A
#
#                               fbi_descr iucr_cd        iucr_secondary month  \
# 0  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110   FIRST DEGREE MURDER     5
# 1            AGGRAVATED BATTERY (INDEX)    041A  AGGRAVATED - HANDGUN     5
# 2  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110   FIRST DEGREE MURDER     5
#
#   day_of_week hour   latitude  longitude  \
# 0           4   11  41.759333 -87.615011
# 1           2    0  41.919410 -87.755999
# 2           2   21  41.875343 -87.684209
#
#                                    location
# 0  POINT (-87.615010941301 41.759333095858)
# 1  POINT (-87.755998547471 41.919409668947)
# 2  POINT (-87.684209058699 41.875343095858)
#
# [3 rows x 25 columns]

# %%
df.shape
# Out:
# (19530, 25)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# case_number                       0
# date                              0
# block                             0
# primary_type                      0
# unique_id                         0
# zip_code                          0
# ward                              0
# community_area                    0
# street_outreach_organization      0
# area                              0
# district                          0
# beat                              0
# age                             255
# sex                             202
# race                            202
# fbi_cd                            0
# fbi_descr                         0
# iucr_cd                           0
# iucr_secondary                    0
# month                             0
# day_of_week                       0
# hour                              0
# latitude                          0
# longitude                         0
# location                          0
# dtype: int64

# %%
df[['age', 'sex', 'race']] = df[['age', 'sex', 'race']].fillna('no_info')

# %%
df.dtypes
# Out:
# case_number                      object
# date                             object
# block                            object
# primary_type                     object
# unique_id                        object
# zip_code                          int64
# ward                              int64
# community_area                   object
# street_outreach_organization     object
# area                              int64
# district                          int64
# beat                              int64
# age                              object
# sex                              object
# race                             object
# fbi_cd                           object
# fbi_descr                        object
# iucr_cd                          object
# iucr_secondary                   object
# month                             int64
# day_of_week                       int64
# hour                              int64
# latitude                        float64
# longitude                       float64
# location                         object
# dtype: object

# %%
df.columns
# Out:
# Index(['case_number', 'date', 'block', 'primary_type', 'unique_id', 'zip_code',
#        'ward', 'community_area', 'street_outreach_organization', 'area',
#        'district', 'beat', 'age', 'sex', 'race', 'fbi_cd', 'fbi_descr',
#        'iucr_cd', 'iucr_secondary', 'month', 'day_of_week', 'hour', 'latitude',
#        'longitude', 'location'],
#       dtype='object')

# %% [markdown]
# Исключим из дат AM и PM.

# %%
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df.head(3)
# Out:
#   case_number                date                block    primary_type  \
# 0    JE235091 2021-05-19 11:20:00    7400  S DR MARTIN  FATAL SHOOTING
# 1    JE240540 2021-05-24 00:01:00  2000  N LARAMIE AVE  FATAL SHOOTING
# 2    JE241639 2021-05-24 21:05:00   500  S OAKLEY BLVD  FATAL SHOOTING
#
#         unique_id  zip_code  ward          community_area  \
# 0  HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1  HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2  HOM-JE241639-1     60612    28          NEAR WEST SIDE
#
#       street_outreach_organization  area  ...  fbi_cd  \
# 0  Acclivus Greater Grand Crossing     1  ...     01A
# 1              ALSO Belmont Cragin     3  ...     04B
# 2                             None     3  ...     01A
#
#                               fbi_descr iucr_cd        iucr_secondary month  \
# 0  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110   FIRST DEGREE MURDER     5
# 1            AGGRAVATED BATTERY (INDEX)    041A  AGGRAVATED - HANDGUN     5
# 2  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110   FIRST DEGREE MURDER     5
#
#   day_of_week hour   latitude  longitude  \
# 0           4   11  41.759333 -87.615011
# 1           2    0  41.919410 -87.755999
# 2           2   21  41.875343 -87.684209
#
#                                    location
# 0  POINT (-87.615010941301 41.759333095858)
# 1  POINT (-87.755998547471 41.919409668947)
# 2  POINT (-87.684209058699 41.875343095858)
#
# [3 rows x 25 columns]

# %% [markdown]
# Для наглядности переведем колонки с месяцами и днями недели к названиям.

# %%
df['month'] = df['date'].dt.month_name() 
df['day_of_week'] = df['date'].dt.day_name() 
df['year'] = df['date'].dt.year

# %%
df.head(3)
# Out:
#   case_number                date                block    primary_type  \
# 0    JE235091 2021-05-19 11:20:00    7400  S DR MARTIN  FATAL SHOOTING
# 1    JE240540 2021-05-24 00:01:00  2000  N LARAMIE AVE  FATAL SHOOTING
# 2    JE241639 2021-05-24 21:05:00   500  S OAKLEY BLVD  FATAL SHOOTING
#
#         unique_id  zip_code  ward          community_area  \
# 0  HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1  HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2  HOM-JE241639-1     60612    28          NEAR WEST SIDE
#
#       street_outreach_organization  area  ...  \
# 0  Acclivus Greater Grand Crossing     1  ...
# 1              ALSO Belmont Cragin     3  ...
# 2                             None     3  ...
#
#                               fbi_descr  iucr_cd        iucr_secondary month  \
# 0  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)     0110   FIRST DEGREE MURDER   May
# 1            AGGRAVATED BATTERY (INDEX)     041A  AGGRAVATED - HANDGUN   May
# 2  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)     0110   FIRST DEGREE MURDER   May
#
#   day_of_week hour   latitude  longitude  \
# 0   Wednesday   11  41.759333 -87.615011
# 1      Monday    0  41.919410 -87.755999
# 2      Monday   21  41.875343 -87.684209
#
#                                    location  year
# 0  POINT (-87.615010941301 41.759333095858)  2021
# 1  POINT (-87.755998547471 41.919409668947)  2021
# 2  POINT (-87.684209058699 41.875343095858)  2021
#
# [3 rows x 26 columns]

# %% [markdown]
# Создадими отдельную колонку с убийством и стрельбой.

# %%
df['type_of_unique_id'] = df['unique_id'].str.extract('(\w+)', expand=True)

# %%
df['type_of_unique_id'] = df['type_of_unique_id'].map({'HOM': 'HOMICIDE', 'SHOOT': 'SHOOTING'})

# %%
df.head(3)
# Out:
#   case_number                date                block    primary_type  \
# 0    JE235091 2021-05-19 11:20:00    7400  S DR MARTIN  FATAL SHOOTING
# 1    JE240540 2021-05-24 00:01:00  2000  N LARAMIE AVE  FATAL SHOOTING
# 2    JE241639 2021-05-24 21:05:00   500  S OAKLEY BLVD  FATAL SHOOTING
#
#         unique_id  zip_code  ward          community_area  \
# 0  HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1  HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2  HOM-JE241639-1     60612    28          NEAR WEST SIDE
#
#       street_outreach_organization  area  ...  iucr_cd        iucr_secondary  \
# 0  Acclivus Greater Grand Crossing     1  ...     0110   FIRST DEGREE MURDER
# 1              ALSO Belmont Cragin     3  ...     041A  AGGRAVATED - HANDGUN
# 2                             None     3  ...     0110   FIRST DEGREE MURDER
#
#   month day_of_week hour   latitude  longitude  \
# 0   May   Wednesday   11  41.759333 -87.615011
# 1   May      Monday    0  41.919410 -87.755999
# 2   May      Monday   21  41.875343 -87.684209
#
#                                    location  year type_of_unique_id
# 0  POINT (-87.615010941301 41.759333095858)  2021          HOMICIDE
# 1  POINT (-87.755998547471 41.919409668947)  2021          HOMICIDE
# 2  POINT (-87.684209058699 41.875343095858)  2021          HOMICIDE
#
# [3 rows x 27 columns]

# %%
df.fbi_cd.unique()
# Out:
# array(['01A', '04B', '00', '03', '15'], dtype=object)

# %% [markdown]
# https://gis.chicagopolice.org/pages/crime_details
# - '01A' - Убийство одного человека другим.
# - '04B' - Незаконное нападение одного лица на другое, при котором преступник использует оружие или потерпевший получает очевидные тяжелые или отягчающие телесные повреждения, включая явные переломы костей, потерю зубов, возможное повреждение внутренних органов, серьезные рваные раны или потерю сознания.
# - '03' - Взятие или попытка забрать что-либо ценное в условиях конфронтации из-под контроля, опеки или заботы другого лица с помощью силы или угрозы силой или насилием и / или путем запугивания жертвы немедленным вредом.
# - '15' - Нарушение законов или постановлений, запрещающих производство, продажу, покупку, транспортировку, владение, сокрытие или использование огнестрельного оружия, режущих инструментов, взрывчатых веществ, зажигательных устройств или другого смертоносного оружия.
# - '00' - Информации нет.

# %%
df.fbi_descr.unique()
# Out:
# array(['HOMICIDE - 1ST OR 2ND DEGREE (INDEX)',
#        'AGGRAVATED BATTERY (INDEX)', 'NON-CRIMINAL', 'ROBBERY (INDEX)',
#        'WEAPONS'], dtype=object)

# %% [markdown]
# https://www.justia.com/criminal/offenses/homicide/first-degree-murder/
# https://www.justia.com/criminal/offenses/homicide/second-degree-murder/
# https://www.law.cornell.edu/wex/aggravated_battery
# https://www.tcsheriff.org/services/victim-services/non-criminal-incidents
# https://www.justia.com/criminal/offenses/theft-crimes/robbery/
# https://thelawdictionary.org/weapon/

# %% [markdown]
# Количество преступлений по годам

# %%
year = df\
    .groupby(['year', 'type_of_unique_id', 'fbi_descr', 'fbi_cd'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
year
# Out:
#     year type_of_unique_id                             fbi_descr fbi_cd  \
# 0   2016          SHOOTING            AGGRAVATED BATTERY (INDEX)    04B
# 1   2020          SHOOTING            AGGRAVATED BATTERY (INDEX)    04B
# 2   2017          SHOOTING            AGGRAVATED BATTERY (INDEX)    04B
# 3   2018          SHOOTING            AGGRAVATED BATTERY (INDEX)    04B
# 4   2019          SHOOTING            AGGRAVATED BATTERY (INDEX)    04B
# 5   2021          SHOOTING            AGGRAVATED BATTERY (INDEX)    04B
# 6   2016          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    01A
# 7   2020          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    01A
# 8   2017          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    01A
# 9   2018          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    01A
# 10  2019          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    01A
# 11  2021          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    01A
# 12  2016          SHOOTING                       ROBBERY (INDEX)     03
# 13  2017          SHOOTING                       ROBBERY (INDEX)     03
# 14  2020          SHOOTING                       ROBBERY (INDEX)     03
# 15  2018          SHOOTING                       ROBBERY (INDEX)     03
# 16  2019          SHOOTING                       ROBBERY (INDEX)     03
# 17  2021          SHOOTING                       ROBBERY (INDEX)     03
# 18  2021          HOMICIDE            AGGRAVATED BATTERY (INDEX)    04B
# 19  2021          HOMICIDE                          NON-CRIMINAL     00
# 20  2020          HOMICIDE            AGGRAVATED BATTERY (INDEX)    04B
# 21  2017          HOMICIDE                          NON-CRIMINAL     00
# 22  2018          HOMICIDE                          NON-CRIMINAL     00
# 23  2018          HOMICIDE            AGGRAVATED BATTERY (INDEX)    04B
# 24  2021          SHOOTING                          NON-CRIMINAL     00
# 25  2016          HOMICIDE            AGGRAVATED BATTERY (INDEX)    04B
# 26  2019          HOMICIDE                          NON-CRIMINAL     00
# 27  2020          HOMICIDE                       ROBBERY (INDEX)     03
# 28  2020          HOMICIDE                          NON-CRIMINAL     00
# 29  2019          HOMICIDE            AGGRAVATED BATTERY (INDEX)    04B
# 30  2021          SHOOTING                               WEAPONS     15
#
#     unique_id_count
# 0              3505
# 1              3378
# 2              2726
# 3              2361
# 4              2165
# 5              1152
# 6               775
# 7               766
# 8               656
# 9               578
# 10              493
# 11              240
# 12              172
# 13              152
# 14              130
# 15              105
# 16               97
# 17               44
# 18               11
# 19                5
# 20                4
# 21                4
# 22                2
# 23                2
# 24                1
# 25                1
# 26                1
# 27                1
# 28                1
# 29                1
# 30                1

# %%
sns.relplot(data=year, x="year", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=15.7/5.27)

# %% [markdown]
# 2016 - самый многочисленный по стрельбе, убийстам и ограблениям. 2021 - самый малочисленный. Посмотрим на месяца.

# %%
month = df\
    .groupby(['month', 'type_of_unique_id', 'fbi_descr'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
month
# Out:
#         month type_of_unique_id                             fbi_descr  \
# 0        July          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1        June          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 2         May          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3      August          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 4   September          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 5       April          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 6     October          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 7       March          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 8     January          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 9    November          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 10   December          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 11   February          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 12        May          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 13       June          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 14       July          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 15     August          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 16  September          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 17    October          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 18      April          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 19    January          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 20   November          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 21   February          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 22      March          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 23   December          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 24     August          SHOOTING                       ROBBERY (INDEX)
# 25      March          SHOOTING                       ROBBERY (INDEX)
# 26        May          SHOOTING                       ROBBERY (INDEX)
# 27   November          SHOOTING                       ROBBERY (INDEX)
# 28    January          SHOOTING                       ROBBERY (INDEX)
# 29    October          SHOOTING                       ROBBERY (INDEX)
# 30       July          SHOOTING                       ROBBERY (INDEX)
# 31      April          SHOOTING                       ROBBERY (INDEX)
# 32   December          SHOOTING                       ROBBERY (INDEX)
# 33   February          SHOOTING                       ROBBERY (INDEX)
# 34  September          SHOOTING                       ROBBERY (INDEX)
# 35       June          SHOOTING                       ROBBERY (INDEX)
# 36    January          HOMICIDE                          NON-CRIMINAL
# 37      April          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 38   February          HOMICIDE                          NON-CRIMINAL
# 39        May          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 40        May          HOMICIDE                          NON-CRIMINAL
# 41   December          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 42      March          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 43    January          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 44      April          HOMICIDE                       ROBBERY (INDEX)
# 45     August          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 46  September          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 47   February          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 48      March          HOMICIDE                          NON-CRIMINAL
# 49   November          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 50        May          SHOOTING                               WEAPONS
# 51       July          HOMICIDE                          NON-CRIMINAL
# 52        May          SHOOTING                          NON-CRIMINAL
# 53       June          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 54       July          HOMICIDE            AGGRAVATED BATTERY (INDEX)
#
#     unique_id_count
# 0              1733
# 1              1680
# 2              1675
# 3              1589
# 4              1304
# 5              1283
# 6              1234
# 7              1074
# 8              1050
# 9               996
# 10              909
# 11              760
# 12              376
# 13              365
# 14              359
# 15              321
# 16              307
# 17              304
# 18              297
# 19              252
# 20              252
# 21              228
# 22              225
# 23              222
# 24               70
# 25               70
# 26               68
# 27               65
# 28               62
# 29               57
# 30               56
# 31               56
# 32               54
# 33               51
# 34               48
# 35               43
# 36                5
# 37                4
# 38                4
# 39                3
# 40                2
# 41                2
# 42                2
# 43                2
# 44                1
# 45                1
# 46                1
# 47                1
# 48                1
# 49                1
# 50                1
# 51                1
# 52                1
# 53                1
# 54                1

# %%
sns.relplot(data=month, x="month", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=17.7/5.27)

# %% [markdown]
# По месяцам отличаются многочисленностью май и все три месяца лета. Посмотрим на дни недели.

# %%
weeks = df\
    .groupby(['day_of_week', 'type_of_unique_id', 'fbi_descr'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
weeks
# Out:
#    day_of_week type_of_unique_id                             fbi_descr  \
# 0       Sunday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1     Saturday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 2       Monday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3       Friday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 4      Tuesday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 5    Wednesday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 6     Thursday          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 7       Sunday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 8     Saturday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 9       Friday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 10      Monday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 11     Tuesday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 12    Thursday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 13   Wednesday          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 14      Sunday          SHOOTING                       ROBBERY (INDEX)
# 15    Saturday          SHOOTING                       ROBBERY (INDEX)
# 16    Thursday          SHOOTING                       ROBBERY (INDEX)
# 17     Tuesday          SHOOTING                       ROBBERY (INDEX)
# 18      Friday          SHOOTING                       ROBBERY (INDEX)
# 19      Monday          SHOOTING                       ROBBERY (INDEX)
# 20   Wednesday          SHOOTING                       ROBBERY (INDEX)
# 21    Saturday          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 22      Monday          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 23     Tuesday          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 24      Friday          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 25      Friday          HOMICIDE                          NON-CRIMINAL
# 26    Thursday          HOMICIDE                          NON-CRIMINAL
# 27      Monday          HOMICIDE                          NON-CRIMINAL
# 28   Wednesday          HOMICIDE                          NON-CRIMINAL
# 29      Sunday          HOMICIDE                          NON-CRIMINAL
# 30    Thursday          HOMICIDE                       ROBBERY (INDEX)
# 31    Thursday          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 32      Sunday          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 33     Tuesday          HOMICIDE                          NON-CRIMINAL
# 34    Saturday          HOMICIDE                          NON-CRIMINAL
# 35     Tuesday          SHOOTING                          NON-CRIMINAL
# 36      Friday          SHOOTING                               WEAPONS
#
#     unique_id_count
# 0              3003
# 1              2963
# 2              2004
# 3              1970
# 4              1844
# 5              1818
# 6              1685
# 7               668
# 8               589
# 9               501
# 10              478
# 11              432
# 12              425
# 13              415
# 14              134
# 15              107
# 16              100
# 17               95
# 18               94
# 19               86
# 20               84
# 21                6
# 22                5
# 23                3
# 24                3
# 25                3
# 26                2
# 27                2
# 28                2
# 29                2
# 30                1
# 31                1
# 32                1
# 33                1
# 34                1
# 35                1
# 36                1

# %%
sns.relplot(data=weeks, x="day_of_week", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=17.7/5.27)

# %% [markdown]
# Большинство преступлений - с пятницы по понедельник. В топе воскресение - стреляют, грабят и убивают. Посмотрим на часы в сутках.

# %%
df['hour_cut'] = pd.cut(df['hour'], bins=6)

# %%
hours = df\
    .groupby(['hour_cut', 'type_of_unique_id', 'fbi_descr'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
hours
# Out:
#             hour_cut type_of_unique_id                             fbi_descr  \
# 0     (19.167, 23.0]          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1    (-0.023, 3.833]          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 2   (15.333, 19.167]          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3     (11.5, 15.333]          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 4      (7.667, 11.5]          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 5     (3.833, 7.667]          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 6     (19.167, 23.0]          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 7   (15.333, 19.167]          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 8    (-0.023, 3.833]          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 9     (11.5, 15.333]          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 10     (7.667, 11.5]          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 11    (3.833, 7.667]          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 12    (19.167, 23.0]          SHOOTING                       ROBBERY (INDEX)
# 13   (-0.023, 3.833]          SHOOTING                       ROBBERY (INDEX)
# 14  (15.333, 19.167]          SHOOTING                       ROBBERY (INDEX)
# 15    (11.5, 15.333]          SHOOTING                       ROBBERY (INDEX)
# 16    (3.833, 7.667]          SHOOTING                       ROBBERY (INDEX)
# 17     (7.667, 11.5]          SHOOTING                       ROBBERY (INDEX)
# 18  (15.333, 19.167]          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 19    (19.167, 23.0]          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 20   (-0.023, 3.833]          HOMICIDE                          NON-CRIMINAL
# 21    (11.5, 15.333]          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 22    (11.5, 15.333]          HOMICIDE                          NON-CRIMINAL
# 23    (19.167, 23.0]          HOMICIDE                          NON-CRIMINAL
# 24   (-0.023, 3.833]          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 25     (7.667, 11.5]          HOMICIDE                          NON-CRIMINAL
# 26    (3.833, 7.667]          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 27  (15.333, 19.167]          HOMICIDE                          NON-CRIMINAL
# 28     (7.667, 11.5]          HOMICIDE                       ROBBERY (INDEX)
# 29  (15.333, 19.167]          SHOOTING                          NON-CRIMINAL
# 30     (7.667, 11.5]          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 31   (-0.023, 3.833]          SHOOTING                               WEAPONS
# 32   (-0.023, 3.833]          SHOOTING  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 33  (15.333, 19.167]          SHOOTING  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 34  (15.333, 19.167]          SHOOTING                               WEAPONS
# 35   (-0.023, 3.833]          SHOOTING                          NON-CRIMINAL
# 36    (19.167, 23.0]          HOMICIDE                               WEAPONS
# 37    (19.167, 23.0]          HOMICIDE                       ROBBERY (INDEX)
# 38  (15.333, 19.167]          HOMICIDE                               WEAPONS
# 39   (-0.023, 3.833]          HOMICIDE                               WEAPONS
# 40    (19.167, 23.0]          SHOOTING  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 41    (19.167, 23.0]          SHOOTING                          NON-CRIMINAL
# 42   (-0.023, 3.833]          HOMICIDE                       ROBBERY (INDEX)
# 43    (3.833, 7.667]          HOMICIDE                          NON-CRIMINAL
# 44     (7.667, 11.5]          HOMICIDE                               WEAPONS
# 45  (15.333, 19.167]          HOMICIDE                       ROBBERY (INDEX)
# 46     (7.667, 11.5]          SHOOTING  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 47    (3.833, 7.667]          HOMICIDE                       ROBBERY (INDEX)
# 48    (3.833, 7.667]          HOMICIDE                               WEAPONS
# 49    (11.5, 15.333]          SHOOTING                               WEAPONS
# 50    (3.833, 7.667]          SHOOTING  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 51    (11.5, 15.333]          SHOOTING                          NON-CRIMINAL
# 52    (11.5, 15.333]          SHOOTING  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 53    (3.833, 7.667]          SHOOTING                          NON-CRIMINAL
# 54    (11.5, 15.333]          HOMICIDE                               WEAPONS
# 55    (11.5, 15.333]          HOMICIDE                       ROBBERY (INDEX)
# 56    (3.833, 7.667]          SHOOTING                               WEAPONS
# 57     (7.667, 11.5]          SHOOTING                               WEAPONS
# 58     (7.667, 11.5]          SHOOTING                          NON-CRIMINAL
# 59    (19.167, 23.0]          SHOOTING                               WEAPONS
#
#     unique_id_count
# 0              4305
# 1              3427
# 2              3299
# 3              2270
# 4              1028
# 5               958
# 6               873
# 7               737
# 8               732
# 9               563
# 10              317
# 11              286
# 12              208
# 13              149
# 14              138
# 15               91
# 16               68
# 17               46
# 18                5
# 19                4
# 20                4
# 21                4
# 22                3
# 23                3
# 24                3
# 25                2
# 26                2
# 27                1
# 28                1
# 29                1
# 30                1
# 31                1
# 32                0
# 33                0
# 34                0
# 35                0
# 36                0
# 37                0
# 38                0
# 39                0
# 40                0
# 41                0
# 42                0
# 43                0
# 44                0
# 45                0
# 46                0
# 47                0
# 48                0
# 49                0
# 50                0
# 51                0
# 52                0
# 53                0
# 54                0
# 55                0
# 56                0
# 57                0
# 58                0
# 59                0

# %%
df.head()
# Out:
#   case_number                date                block        primary_type  \
# 0    JE235091 2021-05-19 11:20:00    7400  S DR MARTIN      FATAL SHOOTING
# 1    JE240540 2021-05-24 00:01:00  2000  N LARAMIE AVE      FATAL SHOOTING
# 2    JE241639 2021-05-24 21:05:00   500  S OAKLEY BLVD      FATAL SHOOTING
# 3    JE224964 2021-05-09 19:24:00      4500  S WOOD ST  NON-FATAL SHOOTING
# 4    JE224974 2021-05-09 19:55:00  9900  S MERRILL AVE  NON-FATAL SHOOTING
#
#           unique_id  zip_code  ward          community_area  \
# 0    HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1    HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2    HOM-JE241639-1     60612    28          NEAR WEST SIDE
# 3  SHOOT-JE224964-1     60609    15                NEW CITY
# 4  SHOOT-JE224974-1     60617     7           SOUTH DEERING
#
#          street_outreach_organization  area  ...        iucr_secondary  month  \
# 0     Acclivus Greater Grand Crossing     1  ...   FIRST DEGREE MURDER    May
# 1                 ALSO Belmont Cragin     3  ...  AGGRAVATED - HANDGUN    May
# 2                                None     3  ...   FIRST DEGREE MURDER    May
# 3                       PBMR New City     1  ...  AGGRAVATED - HANDGUN    May
# 4  Claretian Associates South Deering     2  ...  AGGRAVATED - HANDGUN    May
#
#   day_of_week hour   latitude  longitude  \
# 0   Wednesday   11  41.759333 -87.615011
# 1      Monday    0  41.919410 -87.755999
# 2      Monday   21  41.875343 -87.684209
# 3      Sunday   19  41.810367 -87.669481
# 4      Sunday   19  41.714437 -87.570531
#
#                                    location  year type_of_unique_id  \
# 0  POINT (-87.615010941301 41.759333095858)  2021          HOMICIDE
# 1  POINT (-87.755998547471 41.919409668947)  2021          HOMICIDE
# 2  POINT (-87.684209058699 41.875343095858)  2021          HOMICIDE
# 3  POINT (-87.669480941301 41.810366904142)  2021          SHOOTING
# 4  POINT (-87.570530941301 41.714436904142)  2021          SHOOTING
#
#            hour_cut
# 0     (7.667, 11.5]
# 1   (-0.023, 3.833]
# 2    (19.167, 23.0]
# 3  (15.333, 19.167]
# 4  (15.333, 19.167]
#
# [5 rows x 28 columns]

# %% [markdown]
# Стреляют, убивают и грабят часов с 19 и до 3-4 часов утра.

# %%
df.fbi_descr.unique()
# Out:
# array(['HOMICIDE - 1ST OR 2ND DEGREE (INDEX)',
#        'AGGRAVATED BATTERY (INDEX)', 'NON-CRIMINAL', 'ROBBERY (INDEX)',
#        'WEAPONS'], dtype=object)

# %% [markdown]
# Возраст потерпевших.

# %%
age = df\
    .groupby(['age', 'type_of_unique_id', 'fbi_descr'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
age
# Out:
#         age type_of_unique_id                             fbi_descr  \
# 0   20 - 29          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1    0 - 19          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 2   30 - 39          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3   20 - 29          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 4   40 - 49          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 5   30 - 39          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 6    0 - 19          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 7   50 - 59          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 8   40 - 49          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 9   20 - 29          SHOOTING                       ROBBERY (INDEX)
# 10  no_info          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 11  50 - 59          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 12  30 - 39          SHOOTING                       ROBBERY (INDEX)
# 13  60 - 69          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 14   0 - 19          SHOOTING                       ROBBERY (INDEX)
# 15  40 - 49          SHOOTING                       ROBBERY (INDEX)
# 16  60 - 69          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 17  50 - 59          SHOOTING                       ROBBERY (INDEX)
# 18  70 - 79          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 19  70 - 79          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 20  no_info          SHOOTING                       ROBBERY (INDEX)
# 21  60 - 69          SHOOTING                       ROBBERY (INDEX)
# 22      80+          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 23  20 - 29          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 24      80+          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 25  30 - 39          HOMICIDE                          NON-CRIMINAL
# 26  30 - 39          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 27  20 - 29          HOMICIDE                          NON-CRIMINAL
# 28  70 - 79          SHOOTING                       ROBBERY (INDEX)
# 29   0 - 19          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 30  40 - 49          HOMICIDE                          NON-CRIMINAL
# 31  60 - 69          HOMICIDE                       ROBBERY (INDEX)
# 32  60 - 69          HOMICIDE                          NON-CRIMINAL
# 33  50 - 59          HOMICIDE                          NON-CRIMINAL
# 34  50 - 59          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 35  40 - 49          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 36  20 - 29          SHOOTING                               WEAPONS
# 37  no_info          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 38   0 - 19          HOMICIDE                          NON-CRIMINAL
# 39  40 - 49          SHOOTING                          NON-CRIMINAL
#
#     unique_id_count
# 0              6947
# 1              3260
# 2              3198
# 3              1505
# 4              1030
# 5               808
# 6               579
# 7               438
# 8               314
# 9               274
# 10              232
# 11              188
# 12              164
# 13              149
# 14               87
# 15               83
# 16               78
# 17               52
# 18               24
# 19               22
# 20               22
# 21               16
# 22               13
# 23               10
# 24                9
# 25                5
# 26                5
# 27                3
# 28                2
# 29                2
# 30                2
# 31                1
# 32                1
# 33                1
# 34                1
# 35                1
# 36                1
# 37                1
# 38                1
# 39                1

# %%
sns.relplot(data=age, x="age", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=17.7/5.27, kind="line");

# %% [markdown]
# Посмотрим на пол жертв.

# %%
sex = df\
    .groupby(['sex', 'type_of_unique_id', 'fbi_descr'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
sex
# Out:
#                sex type_of_unique_id                             fbi_descr  \
# 0                M          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1                M          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 2                F          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3                M          SHOOTING                       ROBBERY (INDEX)
# 4                F          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 5          no_info          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 6   (NOT PROVIDED)          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 7                F          SHOOTING                       ROBBERY (INDEX)
# 8          no_info          SHOOTING                       ROBBERY (INDEX)
# 9                M          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 10               M          HOMICIDE                          NON-CRIMINAL
# 11               F          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 12               X          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 13               F          HOMICIDE                          NON-CRIMINAL
# 14         no_info          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 15               M          HOMICIDE                       ROBBERY (INDEX)
# 16               F          SHOOTING                          NON-CRIMINAL
# 17               M          SHOOTING                               WEAPONS
# 18               X          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
#
#     unique_id_count
# 0             13043
# 1              3136
# 2              2003
# 3               635
# 4               369
# 5               179
# 6                59
# 7                44
# 8                21
# 9                14
# 10               10
# 11                5
# 12                3
# 13                3
# 14                2
# 15                1
# 16                1
# 17                1
# 18                1

# %%
sns.relplot(data=sex, x="sex", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=17.7/5.27);

# %% [markdown]
# Нападают, убивают и грабят в основном мужчин.

# %% [markdown]
# Посмотрим на расовый состав потерпевших.

# %%
df.race.unique()
# Out:
# array(['BLK', 'WWH', 'WHI', 'no_info', 'WBH', '(NOT PROVIDED)', 'API',
#        'U', 'I'], dtype=object)

# %% [markdown]
# https://www.opendatanetwork.com/dataset/data.cityofchicago.org/4aki-r3np
# - BLK - черный;
# - WHI - белый;
# - API - житель азиатско-тихоокеанских островов;
# - WBH - черный латиноамериканец;
# - WWH — белый латиноамериканец;
# - I - американский индеец/коренной житель Аляски;
# - U - неизвестно;
# - NOT PROVIDED - информация о расе не предоставлена.

# %%
race = df\
    .groupby(['race', 'type_of_unique_id', 'fbi_descr'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
race
# Out:
#               race type_of_unique_id                             fbi_descr  \
# 0              BLK          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1              BLK          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 2              WWH          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3              WWH          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 4              BLK          SHOOTING                       ROBBERY (INDEX)
# 5              WHI          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 6   (NOT PROVIDED)          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 7          no_info          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 8              WHI          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 9              WBH          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 10             WWH          SHOOTING                       ROBBERY (INDEX)
# 11             API          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 12             WHI          SHOOTING                       ROBBERY (INDEX)
# 13         no_info          SHOOTING                       ROBBERY (INDEX)
# 14               U          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 15             WBH          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 16             BLK          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 17             API          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 18             API          SHOOTING                       ROBBERY (INDEX)
# 19             BLK          HOMICIDE                          NON-CRIMINAL
# 20               I          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 21  (NOT PROVIDED)          SHOOTING                       ROBBERY (INDEX)
# 22             WBH          SHOOTING                       ROBBERY (INDEX)
# 23               U          SHOOTING                       ROBBERY (INDEX)
# 24         no_info          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 25             WWH          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 26               U          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 27             WHI          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 28             BLK          SHOOTING                          NON-CRIMINAL
# 29             BLK          HOMICIDE                       ROBBERY (INDEX)
# 30             WWH          HOMICIDE                          NON-CRIMINAL
# 31             WWH          SHOOTING                               WEAPONS
#
#     unique_id_count
# 0             11934
# 1              2804
# 2              2460
# 3               522
# 4               512
# 5               300
# 6               231
# 7               179
# 8               148
# 9               110
# 10               97
# 11               50
# 12               48
# 13               21
# 14               19
# 15               17
# 16               16
# 17               14
# 18               13
# 19               12
# 20                4
# 21                3
# 22                3
# 23                3
# 24                2
# 25                2
# 26                1
# 27                1
# 28                1
# 29                1
# 30                1
# 31                1

# %%
sns.relplot(data=race, x="race", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=17.7/5.27);

# %% [markdown]
# Нападают с огнестрелом, убивают и грабят в основном черных и латиноамериканцев.

# %%
df.columns
# Out:
# Index(['case_number', 'date', 'block', 'primary_type', 'unique_id', 'zip_code',
#        'ward', 'community_area', 'street_outreach_organization', 'area',
#        'district', 'beat', 'age', 'sex', 'race', 'fbi_cd', 'fbi_descr',
#        'iucr_cd', 'iucr_secondary', 'month', 'day_of_week', 'hour', 'latitude',
#        'longitude', 'location', 'year', 'type_of_unique_id', 'hour_cut'],
#       dtype='object')

# %% [markdown]
# - street outreach organization - Программа Street Outreach позволяет организациям по всей стране помочь бездомным молодым людям найти безопасное жилье. С этой целью программа поддерживает усилия грантополучателей по налаживанию отношений между уличными аутрич-работниками и беглыми, бездомными и уличной молодежью.

# %%
df.street_outreach_organization.unique()
# Out:
# array(['Acclivus Greater Grand Crossing', 'ALSO Belmont Cragin', 'None',
#        'PBMR New City', 'Claretian Associates South Deering',
#        'Roseland Ceasefire - West Pullman | Acclivus West Pullman',
#        'READI 60631', 'READI 60624 | INVC West Garfield Park',
#        'Claretian Associates South Shore', 'INVC Austin',
#        'UCAN North Lawndale | Breakthrough East Garfield Park',
#        'SWOP Chicago Lawn', 'TADC Englewood | READI 60621',
#        'New Life Centers Lower West Side | Enlace Lower West Side',
#        'TADC West Englewood | READI 60631', 'ALSO Humboldt Park',
#        'UCAN North Lawndale | READI 60623',
#        'Claretian Associates South Chicago',
#        'Acclivus Washington Heights',
#        'READI 60644 | INVC West Garfield Park',
#        'ONE Northside Rogers Park', 'Breakthrough East Garfield Park',
#        'READI 60624 | ALSO Humboldt Park', 'TADC Auburn Gresham',
#        'READI 60623 | New Life Centers South Lawndale | Enlace South Lawndale',
#        'New Life Centers Brighton Park', 'Acclivus Fuller Park',
#        'READI 60644 | INVC Austin', 'SWOP Gage Park', 'CRED Southside',
#        'Acclivus Grand Boulevard', 'Project H.O.O.D. Woodlawn',
#        'UCAN North Lawndale | READI 60624 | INVC West Garfield Park',
#        'Together Chicago Near West Side', 'Acclivus Washington Park',
#        'UCAN North Lawndale',
#        'READI 60624 | Breakthrough East Garfield Park',
#        'Acclivus Douglas', 'READI 60621',
#        'UCAN North Lawndale | READI 60624',
#        'PBMR New City | Acclivus Fuller Park',
#        'New Life Centers South Lawndale | Enlace South Lawndale',
#        'READI 60624', 'ALSO Avondale', 'UCAN Roseland',
#        'TADC Englewood | READI 60631',
#        'READI 60623 | Enlace South Lawndale', 'READI 60623',
#        'UCAN Riverdale', 'SWOP Chicago Lawn | READI 60631', 'READI 60644',
#        'UCAN North Lawndale | READI 60624 | Breakthrough East Garfield Park',
#        'TADC Chatham', 'ALSO Albany Park', 'ONE Northside Uptown',
#        'ALSO Humboldt Park | ALSO Belmont Cragin',
#        'CRED Southside | Acclivus West Pullman', 'Acclivus West Pullman',
#        'CRED Southside | Acclivus Washington Heights',
#        'READI 60621 | Acclivus Washington Park',
#        'UCAN North Lawndale | READI 60623 | CRED West Side',
#        'TADC Chatham | Acclivus Greater Grand Crossing',
#        'TADC Englewood | READI 60621 | Project H.O.O.D. Woodlawn',
#        'Roseland Ceasefire - West Pullman | CRED Southside | Acclivus West Pullman',
#        'UCAN Roseland | CRED Southside', 'Enlace Lower West Side',
#        'READI 60621 | Acclivus Greater Grand Crossing',
#        'None | CRED Southside',
#        'READI 60624 | Breakthrough East Garfield Park | ALSO Humboldt Park',
#        'Enlace South Lawndale', 'TADC West Englewood',
#        'READI 60644 | INVC West Garfield Park | INVC Austin',
#        'TADC Englewood | READI 60621 | Acclivus Washington Park',
#        'SWOP Gage Park | READI 60631',
#        'UCAN North Lawndale | READI 60623 | Enlace South Lawndale',
#        'READI 60621 | Project H.O.O.D. Woodlawn',
#        'New Life Centers South Lawndale'], dtype=object)

# %%
df.community_area.unique()
# Out:
# array(['GREATER GRAND CROSSING', 'BELMONT CRAGIN', 'NEAR WEST SIDE',
#        'NEW CITY', 'SOUTH DEERING', 'ROSELAND', 'WEST PULLMAN',
#        'MCKINLEY PARK', 'WEST ENGLEWOOD', 'AUBURN GRESHAM',
#        'WEST GARFIELD PARK', 'SOUTH SHORE', 'AUSTIN',
#        'EAST GARFIELD PARK', 'CHICAGO LAWN', 'LAKE VIEW',
#        'LOWER WEST SIDE', 'HYDE PARK', 'EAST SIDE', 'HERMOSA', 'ASHBURN',
#        'NORTH LAWNDALE', 'CALUMET HEIGHTS', 'WASHINGTON HEIGHTS',
#        'CHATHAM', 'WOODLAWN', 'ROGERS PARK', 'HUMBOLDT PARK',
#        'SOUTH LAWNDALE', 'GRAND BOULEVARD', 'BRIGHTON PARK',
#        'FULLER PARK', 'AVALON PARK', 'GAGE PARK', 'ENGLEWOOD',
#        'LOGAN SQUARE', 'NEAR SOUTH SIDE', 'WASHINGTON PARK', 'DOUGLAS',
#        'KENWOOD', 'HEGEWISCH', 'LOOP', 'ARMOUR SQUARE', 'WEST TOWN',
#        'SOUTH CHICAGO', 'WEST ELSDON', 'NORTH PARK', 'NEAR NORTH SIDE',
#        'AVONDALE', 'MORGAN PARK', 'WEST LAWN', 'RIVERDALE', 'CLEARING',
#        'ALBANY PARK', 'DUNNING', 'BURNSIDE', 'MONTCLARE', 'PORTAGE PARK',
#        'JEFFERSON PARK', 'UPTOWN', 'WEST RIDGE', 'ARCHER HEIGHTS',
#        'OAKLAND', 'NORTH CENTER', 'IRVING PARK', 'LINCOLN SQUARE',
#        'EDGEWATER', 'BRIDGEPORT', 'OHARE', 'LINCOLN PARK',
#        'GARFIELD RIDGE', 'NORWOOD PARK', 'PULLMAN', 'BEVERLY',
#        'MOUNT GREENWOOD', 'EDISON PARK', 'FOREST GLEN'], dtype=object)

# %% [markdown]
# https://metropolitanpeaceinitiatives.org/our-communities/ - карта по районам

# %%
df\
    .query('type_of_unique_id == "HOMICIDE"')\
    .groupby(['street_outreach_organization', 'type_of_unique_id', 'fbi_descr', 'community_area'])\
    .agg(unique_count=('unique_id', 'count'))\
    .head(15)\
    .sort_values('unique_count', ascending=False)\
    .reset_index()
# Out:
#                 street_outreach_organization type_of_unique_id  \
# 0                         ALSO Humboldt Park          HOMICIDE
# 1                        ALSO Belmont Cragin          HOMICIDE
# 2                              ALSO Avondale          HOMICIDE
# 3                           ALSO Albany Park          HOMICIDE
# 4                           Acclivus Douglas          HOMICIDE
# 5                       Acclivus Fuller Park          HOMICIDE
# 6                         ALSO Humboldt Park          HOMICIDE
# 7                       Acclivus Fuller Park          HOMICIDE
# 8                         ALSO Humboldt Park          HOMICIDE
# 9                         ALSO Humboldt Park          HOMICIDE
# 10  ALSO Humboldt Park | ALSO Belmont Cragin          HOMICIDE
# 11                          Acclivus Douglas          HOMICIDE
# 12                          Acclivus Douglas          HOMICIDE
# 13                       ALSO Belmont Cragin          HOMICIDE
# 14                          Acclivus Douglas          HOMICIDE
#
#                                fbi_descr   community_area  unique_count
# 0   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    HUMBOLDT PARK           105
# 1   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)   BELMONT CRAGIN            29
# 2   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)         AVONDALE            17
# 3   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)      ALBANY PARK            16
# 4   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)          DOUGLAS            16
# 5   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)      FULLER PARK            13
# 6   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)        WEST TOWN            11
# 7   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)         NEW CITY             9
# 8   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)          HERMOSA             5
# 9   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)     LOGAN SQUARE             5
# 10  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)   BELMONT CRAGIN             5
# 11  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)          OAKLAND             5
# 12  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)  NEAR SOUTH SIDE             3
# 13            AGGRAVATED BATTERY (INDEX)   BELMONT CRAGIN             1
# 14            AGGRAVATED BATTERY (INDEX)          DOUGLAS             1

# %%
df\
    .query('type_of_unique_id == "SHOOTING"')\
    .groupby(['street_outreach_organization', 'type_of_unique_id', 'fbi_descr', 'community_area'])\
    .agg(unique_count=('unique_id', 'count'))\
    .head(15)\
    .sort_values('unique_count', ascending=False)\
    .reset_index()
# Out:
#                 street_outreach_organization type_of_unique_id  \
# 0                         ALSO Humboldt Park          SHOOTING
# 1                        ALSO Belmont Cragin          SHOOTING
# 2                              ALSO Avondale          SHOOTING
# 3                           Acclivus Douglas          SHOOTING
# 4                           ALSO Albany Park          SHOOTING
# 5                         ALSO Humboldt Park          SHOOTING
# 6                         ALSO Humboldt Park          SHOOTING
# 7                         ALSO Humboldt Park          SHOOTING
# 8                         ALSO Humboldt Park          SHOOTING
# 9   ALSO Humboldt Park | ALSO Belmont Cragin          SHOOTING
# 10                       ALSO Belmont Cragin          SHOOTING
# 11                             ALSO Avondale          SHOOTING
# 12                          ALSO Albany Park          SHOOTING
# 13                        ALSO Humboldt Park          SHOOTING
# 14                        ALSO Humboldt Park          SHOOTING
#
#                      fbi_descr  community_area  unique_count
# 0   AGGRAVATED BATTERY (INDEX)   HUMBOLDT PARK           520
# 1   AGGRAVATED BATTERY (INDEX)  BELMONT CRAGIN           161
# 2   AGGRAVATED BATTERY (INDEX)        AVONDALE            83
# 3   AGGRAVATED BATTERY (INDEX)         DOUGLAS            83
# 4   AGGRAVATED BATTERY (INDEX)     ALBANY PARK            79
# 5   AGGRAVATED BATTERY (INDEX)       WEST TOWN            74
# 6   AGGRAVATED BATTERY (INDEX)    LOGAN SQUARE            28
# 7   AGGRAVATED BATTERY (INDEX)         HERMOSA            26
# 8              ROBBERY (INDEX)   HUMBOLDT PARK            19
# 9   AGGRAVATED BATTERY (INDEX)  BELMONT CRAGIN            18
# 10             ROBBERY (INDEX)  BELMONT CRAGIN             6
# 11             ROBBERY (INDEX)        AVONDALE             4
# 12             ROBBERY (INDEX)     ALBANY PARK             3
# 13             ROBBERY (INDEX)       WEST TOWN             2
# 14             ROBBERY (INDEX)         HERMOSA             1

# %% [markdown]
# Alliance of Local Service Organizations(ALSO) - Альянс местных сервисных организаций
# https://also-chicago.org/also_site/

# %%
org = df\
    .query('street_outreach_organization in ("ALSO Humboldt Park", "ALSO Belmont Cragin", "ALSO Avondale", "Acclivus Douglas", "ALSO Albany Park")')\
    .groupby(['street_outreach_organization','type_of_unique_id', 'fbi_descr', 'community_area'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
org
# Out:
#    street_outreach_organization type_of_unique_id  \
# 0            ALSO Humboldt Park          SHOOTING
# 1           ALSO Belmont Cragin          SHOOTING
# 2            ALSO Humboldt Park          HOMICIDE
# 3                 ALSO Avondale          SHOOTING
# 4              Acclivus Douglas          SHOOTING
# 5              ALSO Albany Park          SHOOTING
# 6            ALSO Humboldt Park          SHOOTING
# 7           ALSO Belmont Cragin          HOMICIDE
# 8            ALSO Humboldt Park          SHOOTING
# 9            ALSO Humboldt Park          SHOOTING
# 10             Acclivus Douglas          SHOOTING
# 11           ALSO Humboldt Park          SHOOTING
# 12                ALSO Avondale          HOMICIDE
# 13             Acclivus Douglas          HOMICIDE
# 14             ALSO Albany Park          HOMICIDE
# 15           ALSO Humboldt Park          HOMICIDE
# 16             Acclivus Douglas          SHOOTING
# 17          ALSO Belmont Cragin          SHOOTING
# 18           ALSO Humboldt Park          HOMICIDE
# 19           ALSO Humboldt Park          HOMICIDE
# 20             Acclivus Douglas          HOMICIDE
# 21                ALSO Avondale          SHOOTING
# 22             Acclivus Douglas          HOMICIDE
# 23             Acclivus Douglas          SHOOTING
# 24             ALSO Albany Park          SHOOTING
# 25           ALSO Humboldt Park          SHOOTING
# 26             Acclivus Douglas          SHOOTING
# 27           ALSO Humboldt Park          SHOOTING
# 28             Acclivus Douglas          HOMICIDE
# 29          ALSO Belmont Cragin          HOMICIDE
#
#                                fbi_descr   community_area  unique_id_count
# 0             AGGRAVATED BATTERY (INDEX)    HUMBOLDT PARK              520
# 1             AGGRAVATED BATTERY (INDEX)   BELMONT CRAGIN              161
# 2   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    HUMBOLDT PARK              105
# 3             AGGRAVATED BATTERY (INDEX)         AVONDALE               83
# 4             AGGRAVATED BATTERY (INDEX)          DOUGLAS               83
# 5             AGGRAVATED BATTERY (INDEX)      ALBANY PARK               79
# 6             AGGRAVATED BATTERY (INDEX)        WEST TOWN               74
# 7   HOMICIDE - 1ST OR 2ND DEGREE (INDEX)   BELMONT CRAGIN               29
# 8             AGGRAVATED BATTERY (INDEX)     LOGAN SQUARE               28
# 9             AGGRAVATED BATTERY (INDEX)          HERMOSA               26
# 10            AGGRAVATED BATTERY (INDEX)          OAKLAND               21
# 11                       ROBBERY (INDEX)    HUMBOLDT PARK               19
# 12  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)         AVONDALE               17
# 13  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)          DOUGLAS               16
# 14  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)      ALBANY PARK               16
# 15  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)        WEST TOWN               11
# 16                       ROBBERY (INDEX)          DOUGLAS                7
# 17                       ROBBERY (INDEX)   BELMONT CRAGIN                6
# 18  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)     LOGAN SQUARE                5
# 19  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)          HERMOSA                5
# 20  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)          OAKLAND                5
# 21                       ROBBERY (INDEX)         AVONDALE                4
# 22  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)  NEAR SOUTH SIDE                3
# 23            AGGRAVATED BATTERY (INDEX)  NEAR SOUTH SIDE                3
# 24                       ROBBERY (INDEX)      ALBANY PARK                3
# 25                       ROBBERY (INDEX)        WEST TOWN                2
# 26                       ROBBERY (INDEX)          OAKLAND                2
# 27                       ROBBERY (INDEX)          HERMOSA                1
# 28            AGGRAVATED BATTERY (INDEX)          DOUGLAS                1
# 29            AGGRAVATED BATTERY (INDEX)   BELMONT CRAGIN                1

# %%
sns.relplot(data=org, x="street_outreach_organization", y="unique_id_count", hue="fbi_descr", height=3.27, aspect=17.7/5.27);

# %%
df['community_area'].value_counts().head(10)
# Out:
# AUSTIN                    2067
# NORTH LAWNDALE            1196
# HUMBOLDT PARK              944
# WEST GARFIELD PARK         877
# ENGLEWOOD                  847
# WEST ENGLEWOOD             814
# AUBURN GRESHAM             797
# EAST GARFIELD PARK         775
# GREATER GRAND CROSSING     771
# ROSELAND                   734
# Name: community_area, dtype: int64

# %%
df\
    .query('community_area in ("AUSTIN", "NORTH LAWNDALE", "HUMBOLDT PARK", "WEST GARFIELD PARK", "ENGLEWOOD")')\
    .groupby(['type_of_unique_id', 'fbi_descr', 'community_area'])\
    .agg(unique_id_count=('unique_id', 'count'))\
    .sort_values('unique_id_count', ascending=False)\
    .reset_index()
# Out:
#    type_of_unique_id                             fbi_descr  \
# 0           SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1           SHOOTING            AGGRAVATED BATTERY (INDEX)
# 2           SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3           SHOOTING            AGGRAVATED BATTERY (INDEX)
# 4           SHOOTING            AGGRAVATED BATTERY (INDEX)
# 5           HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 6           HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 7           HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 8           HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 9           HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 10          SHOOTING                       ROBBERY (INDEX)
# 11          SHOOTING                       ROBBERY (INDEX)
# 12          SHOOTING                       ROBBERY (INDEX)
# 13          SHOOTING                       ROBBERY (INDEX)
# 14          SHOOTING                       ROBBERY (INDEX)
# 15          HOMICIDE                          NON-CRIMINAL
# 16          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 17          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 18          HOMICIDE                          NON-CRIMINAL
# 19          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 20          HOMICIDE                       ROBBERY (INDEX)
#
#         community_area  unique_id_count
# 0               AUSTIN             1601
# 1       NORTH LAWNDALE              971
# 2        HUMBOLDT PARK              751
# 3   WEST GARFIELD PARK              690
# 4            ENGLEWOOD              649
# 5               AUSTIN              382
# 6       NORTH LAWNDALE              178
# 7            ENGLEWOOD              170
# 8        HUMBOLDT PARK              156
# 9   WEST GARFIELD PARK              145
# 10              AUSTIN               82
# 11      NORTH LAWNDALE               46
# 12  WEST GARFIELD PARK               41
# 13       HUMBOLDT PARK               36
# 14           ENGLEWOOD               26
# 15           ENGLEWOOD                2
# 16              AUSTIN                1
# 17       HUMBOLDT PARK                1
# 18              AUSTIN                1
# 19  WEST GARFIELD PARK                1
# 20      NORTH LAWNDALE                1

# %%
df.groupby(['year', 'type_of_unique_id', 'fbi_descr'])\
    .agg(case_number_count=('case_number', 'count'), case_number_unique=('case_number', 'nunique'))\
    .sort_values('case_number_count', ascending=False)\
    .reset_index()
# Out:
#     year type_of_unique_id                             fbi_descr  \
# 0   2016          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 1   2020          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 2   2017          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 3   2018          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 4   2019          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 5   2021          SHOOTING            AGGRAVATED BATTERY (INDEX)
# 6   2016          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 7   2020          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 8   2017          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 9   2018          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 10  2019          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 11  2021          HOMICIDE  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)
# 12  2016          SHOOTING                       ROBBERY (INDEX)
# 13  2017          SHOOTING                       ROBBERY (INDEX)
# 14  2020          SHOOTING                       ROBBERY (INDEX)
# 15  2018          SHOOTING                       ROBBERY (INDEX)
# 16  2019          SHOOTING                       ROBBERY (INDEX)
# 17  2021          SHOOTING                       ROBBERY (INDEX)
# 18  2021          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 19  2021          HOMICIDE                          NON-CRIMINAL
# 20  2020          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 21  2017          HOMICIDE                          NON-CRIMINAL
# 22  2018          HOMICIDE                          NON-CRIMINAL
# 23  2018          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 24  2021          SHOOTING                          NON-CRIMINAL
# 25  2016          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 26  2019          HOMICIDE                          NON-CRIMINAL
# 27  2020          HOMICIDE                       ROBBERY (INDEX)
# 28  2020          HOMICIDE                          NON-CRIMINAL
# 29  2019          HOMICIDE            AGGRAVATED BATTERY (INDEX)
# 30  2021          SHOOTING                               WEAPONS
#
#     case_number_count  case_number_unique
# 0                3505                2897
# 1                3378                2697
# 2                2726                2231
# 3                2361                1945
# 4                2165                1759
# 5                1152                 969
# 6                 775                 737
# 7                 766                 736
# 8                 656                 609
# 9                 578                 553
# 10                493                 473
# 11                240                 229
# 12                172                 164
# 13                152                 139
# 14                130                 121
# 15                105                 103
# 16                 97                  90
# 17                 44                  41
# 18                 11                  11
# 19                  5                   4
# 20                  4                   4
# 21                  4                   4
# 22                  2                   2
# 23                  2                   2
# 24                  1                   1
# 25                  1                   1
# 26                  1                   1
# 27                  1                   1
# 28                  1                   1
# 29                  1                   1
# 30                  1                   1

# %%
df.head()
# Out:
#   case_number                date                block        primary_type  \
# 0    JE235091 2021-05-19 11:20:00    7400  S DR MARTIN      FATAL SHOOTING
# 1    JE240540 2021-05-24 00:01:00  2000  N LARAMIE AVE      FATAL SHOOTING
# 2    JE241639 2021-05-24 21:05:00   500  S OAKLEY BLVD      FATAL SHOOTING
# 3    JE224964 2021-05-09 19:24:00      4500  S WOOD ST  NON-FATAL SHOOTING
# 4    JE224974 2021-05-09 19:55:00  9900  S MERRILL AVE  NON-FATAL SHOOTING
#
#           unique_id  zip_code  ward          community_area  \
# 0    HOM-JE235091-1     60619     6  GREATER GRAND CROSSING
# 1    HOM-JE240540-1     60639    36          BELMONT CRAGIN
# 2    HOM-JE241639-1     60612    28          NEAR WEST SIDE
# 3  SHOOT-JE224964-1     60609    15                NEW CITY
# 4  SHOOT-JE224974-1     60617     7           SOUTH DEERING
#
#          street_outreach_organization  area  ...        iucr_secondary  month  \
# 0     Acclivus Greater Grand Crossing     1  ...   FIRST DEGREE MURDER    May
# 1                 ALSO Belmont Cragin     3  ...  AGGRAVATED - HANDGUN    May
# 2                                None     3  ...   FIRST DEGREE MURDER    May
# 3                       PBMR New City     1  ...  AGGRAVATED - HANDGUN    May
# 4  Claretian Associates South Deering     2  ...  AGGRAVATED - HANDGUN    May
#
#   day_of_week hour   latitude  longitude  \
# 0   Wednesday   11  41.759333 -87.615011
# 1      Monday    0  41.919410 -87.755999
# 2      Monday   21  41.875343 -87.684209
# 3      Sunday   19  41.810367 -87.669481
# 4      Sunday   19  41.714437 -87.570531
#
#                                    location  year type_of_unique_id  \
# 0  POINT (-87.615010941301 41.759333095858)  2021          HOMICIDE
# 1  POINT (-87.755998547471 41.919409668947)  2021          HOMICIDE
# 2  POINT (-87.684209058699 41.875343095858)  2021          HOMICIDE
# 3  POINT (-87.669480941301 41.810366904142)  2021          SHOOTING
# 4  POINT (-87.570530941301 41.714436904142)  2021          SHOOTING
#
#            hour_cut
# 0     (7.667, 11.5]
# 1   (-0.023, 3.833]
# 2    (19.167, 23.0]
# 3  (15.333, 19.167]
# 4  (15.333, 19.167]
#
# [5 rows x 28 columns]

# %%
df\
    .groupby('hour')\
    .agg(unique_count=('unique_id', 'count'))\
    .sort_values('unique_count', ascending=False)\
    .reset_index().plot(kind='bar', figsize=(15,4));

# %%
import matplotlib.pyplot as plt

# %%
df\
    .groupby('hour')\
    .agg(unique_count=('unique_id', 'count'))\
    .sort_values('unique_count', ascending=False).plot.pie(subplots=True)
#df.plot(x="unique_count", y=["hour", "fbi_descr", "type_of_unique_id"])
#plt.show()
# Out:
# array([<Axes: ylabel='unique_count'>], dtype=object)
